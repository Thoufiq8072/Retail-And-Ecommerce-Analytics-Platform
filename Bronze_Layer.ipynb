# %%
# %sql
USE CATALOG ecommerce_catalog;
USE SCHEMA ecommerce_bronze;

# %% [markdown]
# Delta table will not support column space so we need to convert space into "_"

# %%
def clean_column_names(df):
    new_columns = [c.strip().replace(" ", "_").replace("-", "_").lower() for c in df.columns]
    return df.toDF(*new_columns)

# %% [markdown]
# Customers

# %%
from pyspark.sql.functions import current_timestamp, col

df_customers = (
    spark.read
        .option("header", "true")
        .option("inferSchema", "true")
        .csv("/Volumes/ecommerce_catalog/ecommerce_schema/volume/global_fashion/customers.csv")
        .withColumn("ingestion_ts", current_timestamp())
        .withColumn("source_file", col("_metadata.file_path"))
)

df_customers = clean_column_names(df_customers)


df_customers.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("ecommerce_bronze.customers")
display(df_customers)

# %% [markdown]
# Discounts

# %%
df_discounts = (
    spark.read
        .option("header", "true")
        .option("inferSchema", "true")
        .csv("/Volumes/ecommerce_catalog/ecommerce_schema/volume/global_fashion/discounts.csv")
        .withColumn("ingestion_ts", current_timestamp())
        .withColumn("source_file", col("_metadata.file_path"))
)
df_discounts = clean_column_names(df_discounts)
df_discounts.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("ecommerce_bronze.discounts")
display(df_discounts)

# %% [markdown]
# Employees

# %%
df_employees = (
    spark.read
        .option("header", "true")
        .option("inferSchema", "true")
        .csv("/Volumes/ecommerce_catalog/ecommerce_schema/volume/global_fashion/employees.csv")
        .withColumn("ingestion_ts", current_timestamp())
        .withColumn("source_file", col("_metadata.file_path"))
)

df_employees = clean_column_names(df_employees)
df_employees.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("ecommerce_bronze.employees")
display(df_employees)

# %% [markdown]
# Products

# %%
df_products = (
    spark.read
        .option("header", "true")
        .option("inferSchema", "true")
        .csv("/Volumes/ecommerce_catalog/ecommerce_schema/volume/global_fashion/products.csv")
        .withColumn("ingestion_ts", current_timestamp())
        .withColumn("source_file", col("_metadata.file_path"))
)
df_products= clean_column_names(df_products)
df_products.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("ecommerce_bronze.products")
display(df_products)

# %% [markdown]
# Stores

# %%
df_stores = (
    spark.read
        .option("header", "true")
        .option("inferSchema", "true")
        .csv("/Volumes/ecommerce_catalog/ecommerce_schema/volume/global_fashion/stores.csv")
        .withColumn("ingestion_ts", current_timestamp())
        .withColumn("source_file", col("_metadata.file_path"))
)

df_stores = clean_column_names(df_stores)
df_stores.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("ecommerce_bronze.stores")
display(df_stores)

# %% [markdown]
# Transactions

# %%
df_transactions = (
    spark.read
        .option("header", "true")
        .option("inferSchema", "true")
        .csv("/Volumes/ecommerce_catalog/ecommerce_schema/volume/global_fashion/transactions.csv")
        .withColumn("ingestion_ts", current_timestamp())
        .withColumn("source_file", col("_metadata.file_path"))
)


df_transactions = clean_column_names(df_transactions)
df_transactions.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("ecommerce_bronze.transactions")
display(df_transactions)
