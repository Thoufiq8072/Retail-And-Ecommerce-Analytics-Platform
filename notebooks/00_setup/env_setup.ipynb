# %%
# %pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import sys
import os
from dotenv import load_dotenv

load_dotenv()

sys.path.append(
    f"/Workspace/Users/{os.getenv("WORKSPACE_USERNAME")}/Retail-And-Ecommerce-Analytics-Platform"
)
# Out:
# Path: /Workspace/Users/mohammedthoufiq9360@gmail.com/Retail-And-Ecommerce-Analytics-Platform

# %%
from src.configs import (
    CATALOG_NAME,
    RAW_SCHEMA,
    BRONZE_SCHEMA,
    SILVER_SCHEMA,
    GOLD_SCHEMA,
    RAW_VOLUME
)

print("Catalog:", CATALOG_NAME)
print("Schemas:", RAW_SCHEMA, BRONZE_SCHEMA, SILVER_SCHEMA, GOLD_SCHEMA)
# Out:
# Catalog: retail_analytics
# Schemas: raw bronze silver gold

# %%
spark.sql(f"CREATE CATALOG IF NOT EXISTS {CATALOG_NAME}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG_NAME}.{RAW_SCHEMA}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG_NAME}.{BRONZE_SCHEMA}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG_NAME}.{SILVER_SCHEMA}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG_NAME}.{GOLD_SCHEMA}")
spark.sql(f"CREATE VOLUME IF NOT EXISTS {CATALOG_NAME}.{RAW_SCHEMA}.{RAW_VOLUME}")
# Out:
# DataFrame[]
