# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
 # %reload_ext autoreload

# %% [markdown]
# ## Installing Kaggle for Data Ingestion

# %%
# %pip install kaggle
# %pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
 # %restart_python

# %% [markdown]
# ### Importing the needed Modules

# %%
import os
import sys
sys.path.append(f"/Workspace/Users/{os.getenv("WORKSPACE_USERNAME")}/Retail-And-Ecommerce-Analytics-Platform")
from src.paths import INGESTION_PATH

# %% [markdown]
# ### creaing folder inside the volume

# %%
os.makedirs(INGESTION_PATH, exist_ok=True)

# %% [markdown]
# ### Ingesting the data using Kaggle API

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

api.dataset_download_files(
    "ricgomes/global-fashion-retail-stores-dataset",
    path=INGESTION_PATH,
    unzip=True
)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ricgomes/global-fashion-retail-stores-dataset

# %%
display(dbutils.fs.ls(INGESTION_PATH))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
